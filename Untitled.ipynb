# %%
import matplotlib.image as img
import numpy as np

# %%
image = np.array(img.imread("Data/Part 1/Part 1/000001.jpg"))

# %%
import matplotlib.pyplot as imgg

# %%
imgg.imshow(image)

# %%
for i in range(95, 226+95):    
    image[i][71][0] = 0
    image[i][71][1] = 255
    image[i][71][2] = 0
    image[i][71+313][0] = 0
    image[i][71+313][1] = 255
    image[i][71+313][2] = 0
for j in range(71,71+313):
    image[95][j][0] = 0
    image[95][j][1] = 255
    image[95][j][2] = 0
    image[95+226][j][0] = 0
    image[95+226][j][1] = 255
    image[95+226][j][2] = 0

# %%
imgg.imshow(image)

# %%
from PIL import Image

# %%
size = 640,640
im = Image.open("Data/Part 1/Part 1/000001.jpg")
im = im.thumbnail(size, Image.ANTIALIAS)
image = np.array(im)
image.shape
# Out:
# ()

# %%
im = Image.open("Data/Part 1/Part 1/000001.jpg")
new_img = im.resize((512,512), Image.ANTIALIAS)
temp = np.array(new_img)
temp.shape
imgg.imshow(temp)

# %%
leftIntersection = max(scores[0], y[0])
rightIntersection = min(scores[0] + scores[2], y[0] + y[2])
topIntersection = min[scores[1], y[1]]
bottomIntersection = max(scores[1] + scores[3], y[1] + y[3])
if (left < right && top < bottom)
    intersection = (right - left) * (bottom - top)
    loss = ((y[2] * y[3]) - intersection)
else
    loss = (y[2] * y[3])
